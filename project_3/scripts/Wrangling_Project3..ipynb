# %%
# load Python packages used data wrangling
import pandas as pd
import numpy as np
import datetime as datetime

# Datasets
health = pd.read_csv("https://raw.githubusercontent.com/biodatascience/datasci611/gh-pages/data/project2_2019/HEALTH_INS_ENTRY_191102.tsv", sep = '\t')
client = pd.read_csv('https://raw.githubusercontent.com/biodatascience/datasci611/gh-pages/data/project2_2019/CLIENT_191102.tsv',sep='\t')

# merge the two datasets
health['Entry'] =  pd.to_datetime(health['Health Insurance Start Date (Entry)'], format='%m/%d/%Y')
health1 = health.drop(['EE Provider ID','EE UID', 'Client Unique ID','Covered (Entry)','Health Insurance End Date (Entry)','Provider (4307-provider)','Recordset ID (4307-recordset_id)','Date Added (4307-date_added)'], axis=1)
client1 = client.drop(['EE Provider ID','EE UID','Client Unique ID',], axis=1)

ch = client1.merge(health1, on=['Client ID'], how='left')

# %%
ch.head()
# Out:
#    Client ID  Client Age at Entry  Client Age at Exit Client Gender  \
# 0     397941                 60.0                61.0        Female
# 1     397941                 60.0                61.0        Female
# 2     397941                 60.0                61.0        Female
# 3     397941                 60.0                61.0        Female
# 4     397941                 60.0                61.0        Female
#
#   Client Primary Race               Client Ethnicity Client Veteran Status  \
# 0         White (HUD)  Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 1         White (HUD)  Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 2         White (HUD)  Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 3         White (HUD)  Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 4         White (HUD)  Non-Hispanic/Non-Latino (HUD)              No (HUD)
#
#              Health Insurance Type (Entry)  \
# 0     Employer - Provided Health Insurance
# 1  Health Insurance obtained through COBRA
# 2           Indian Health Services Program
# 3                                 MEDICAID
# 4                                 MEDICARE
#
#   Health Insurance Start Date (Entry)      Entry
# 0                           4/20/2015 2015-04-20
# 1                           4/20/2015 2015-04-20
# 2                            6/9/2015 2015-06-09
# 3                           4/20/2014 2014-04-20
# 4                           4/20/2015 2015-04-20

# %%
health.head()
# Out:
#                                       EE Provider ID  EE UID  \
# 0  Urban Ministries of Durham - Durham County - S...  687901
# 1  Urban Ministries of Durham - Durham County - S...  687901
# 2  Urban Ministries of Durham - Durham County - S...  687901
# 3  Urban Ministries of Durham - Durham County - S...  687901
# 4  Urban Ministries of Durham - Durham County - S...  687901
#
#        Client Unique ID  Client ID Covered (Entry)  \
# 0  pbkf09291954p610b236     397941              No
# 1  pbkf09291954p610b236     397941              No
# 2  pbkf09291954p610b236     397941              No
# 3  pbkf09291954p610b236     397941              No
# 4  pbkf09291954p610b236     397941              No
#
#              Health Insurance Type (Entry)  \
# 0     Employer - Provided Health Insurance
# 1  Health Insurance obtained through COBRA
# 2           Indian Health Services Program
# 3                                 MEDICAID
# 4                                 MEDICARE
#
#   Health Insurance Start Date (Entry) Health Insurance End Date (Entry)  \
# 0                           4/20/2015                               NaN
# 1                           4/20/2015                               NaN
# 2                            6/9/2015                               NaN
# 3                           4/20/2014                               NaN
# 4                           4/20/2015                               NaN
#
#                             Provider (4307-provider)  \
# 0   Urban Ministries of Durham - Durham County(1562)
# 1   Urban Ministries of Durham - Durham County(1562)
# 2  Urban Ministries of Durham - Durham County - S...
# 3   Urban Ministries of Durham - Durham County(1562)
# 4   Urban Ministries of Durham - Durham County(1562)
#
#    Recordset ID (4307-recordset_id) Date Added (4307-date_added)
# 0                           2261535                    7/16/2015
# 1                           2261536                    7/16/2015
# 2                           4677504                   12/22/2016
# 3                           1959563                    4/21/2015
# 4                           2261533                    7/16/2015

# %%
health['Entry'] =  pd.to_datetime(health[health.columns[7]], format='%m/%d/%Y')
